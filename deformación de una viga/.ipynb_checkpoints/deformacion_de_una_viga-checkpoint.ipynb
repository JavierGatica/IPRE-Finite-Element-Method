# %% [markdown]
# # Solución numérica para la deformación de una viga en régimen lineal

# %% [markdown]
# ## Formulación matemática del problema:
#
# En este notebook se generan soluciones computacionales para la ecuación diferencial parcial (EDP) que describe la deformación elástica de un sólido cuando a este es sometido a un campo de fuerzas en el espacio, para deformaciones pequeñas <sup>(1)</sup>. La ecuación a resolver corresponde a la siguiente:
#
# $$
# \begin{align}
# -\nabla\cdot\sigma &= f\hbox{ in }\Omega,\\
# \end{align}
# $$
#
# Se definen los parámetros
# $$
# \begin{align}
# \sigma &= \lambda\,\hbox{tr}\,(\varepsilon) I + 2\mu\varepsilon,\\
# \varepsilon &= \frac{1}{2}\left(\nabla u + (\nabla u)^{\top}\right),
# \end{align}
# $$
#
# Donde $\sigma$ es el tensor de tracción unitaria (stress) con parámetros de Lamé $\lambda$ y $\mu$ correspondientes al módulo elástico para cargas axiales y cortantes respectivamente, $\varepsilon$ es el tensor de desplazamiento unitario (Cauchy's strain tensor) y $u$ es el campo vectorial de deformaciones del cuerpo, por lo que se resuelve la EDP para $u$. Se propone la formulación variacional del problema:
#
# $$-\int_\Omega (\nabla\cdot\sigma) \cdot v  =
# \int_\Omega f\cdot v ,$$
#
# Dado que el término $\nabla\cdot\sigma$ es de segundo orden, se puede integrar por partes de la siguiente forma:
#
# $$
# \begin{align}
# -\int_\Omega (\nabla\cdot\sigma) \cdot v
# &= \int_\Omega \sigma : \nabla v - \int_{\partial\Omega}
# (\sigma\cdot \hat{n})\cdot v ,
# \end{align}
# $$
#
# Considerando que $\sigma \cdot \hat{n}$ corresponde al stress en la frontera del sólido, se puede caracterizar este vector como una condición de borde de Dirichlet definido como $T = \sigma \cdot \hat{n}$ en una región específica de la frontera $\partial \Omega_T \subseteq \partial \Omega$, tal que el resto de la frontera se define con una condición de Dirichlet de deformación nula. Además, es posible simplificar el producto interno $\sigma (u) : \nabla v$ como $\sigma (u) : \varepsilon (v)$, ya que la parte sólo la parte simétrica de $\nabla v$ no entrega un resultado identicamente nulo en el producto interno. La forma variacional final resulta:
#
# $$
# \int_\Omega \sigma : \varepsilon (v)  =
# \int_\Omega f\cdot v
# + \int_{\partial\Omega_T} T\cdot v,
# $$
#
# El problema se puede expresar como una ecuación expresada en una forma bilineal y otra lineal para encontrar $u\in V$:
#
# $$
# \begin{equation}
# a(u,v) = L(v)\quad\forall v\in\hat{V},
# \end{equation}
# $$
#
# Donde:
#
# $$
# \begin{align}
# a(u,v) &= \int_\Omega\sigma(u) :\nabla v,\\
# \sigma(u) &= \lambda(\nabla\cdot u)I + \mu(\nabla u + (\nabla u)^{\top}),\\
# L(v) &= \int_\Omega f\cdot v + \int_{\partial\Omega_T}
# T\cdot v,
# \end{align}
# $$
#
#
# Formulación del problema basada en: [The equations of linear elasticity](https://fenicsproject.org/pub/tutorial/html/._ftut1008.html)
#
# Notas al pie de página:
#
# (1) Para encontrar soluciones para sólidos con desplazamientos mayores investigar en análisis no lineal de estructuras

# %% [markdown]
# ## Elementos necesarios para la implementación:
#
# La construcción del sólido a utilizar y la discretización por elementos finítos se realiza en el programa <b>Gmsh</b>, para luego importar la malla obtenida como un archivo .msh. Para poder encontrar soluciones numéricas a partir de la malla se utiliza el módulo <b>NGSolve</b>. Se define una clase para poder trabajar con varias mallas y parámetros en el problema:

# %%
from ngsolve import *
from ngsolve.webgui import Draw
from netgen.read_gmsh import ReadGmsh

# %%
class Beam:
    
    def __init__(self, mesh, order, lam, mu, b, T):
        
        self.mesh = mesh
        self.order = order
        self.lam = lam
        self.mu = mu
        self.b = b
        self.T = T
        
        if mesh.dim == 3:
            self.freebnd = 'top|bottom|left|right|end'
            self.fixedbnd = 'wall'
        elif mesh.dim == 2:
            self.freebnd = 'top|bottom|right'
            self.fixedbnd = 'left'


    def define_space(self):
        
        self.V = VectorH1(self.mesh,order = self.order, dirichlet = self.fixedbnd)
        self.u = self.V.TrialFunction()
        self.v = self.V.TestFunction()
   
    def define_forms(self):
        
        global sigma
        sigma = lambda u: self.lam*Id(self.mesh.dim) * (epsilon(u)[0]+epsilon(u)[1]+epsilon(u)[2])+ 2*self.mu*epsilon(u)
        global epsilon
        epsilon = lambda u: 0.5*(grad(u) + grad(u).trans)
        
        self.a = BilinearForm(self.V)
        self.a += InnerProduct(sigma(self.u), epsilon(self.v))*dx
        self.a.Assemble()
        
        self.f = LinearForm(self.V)
        self.f += self.b*self.v*dx + self.T*self.v*ds(definedon = self.freebnd)
        self.f.Assemble()
    
    def solve_system(self):
        
        self.gfu = GridFunction(self.V)
        # se implementa la condicion de dirichlet
        self.gfu.Set(tuple([0 for _ in range(self.mesh.dim)]), definedon = mesh.Boundaries(self.fixedbnd))
        
        r = self.f.vec.CreateVector()
        r.data = self.f.vec - self.a.mat * self.gfu.vec
        self.gfu.vec.data += self.a.mat.Inverse(freedofs=self.V.FreeDofs()) * r
        
    def solve(self, draw = False):
        self.define_space()
        self.define_forms()
        self.solve_system()
        if draw:
            Draw(self.gfu, deformation = True)

# %% [markdown]
# Luego de definir esta clase con parámetros convenientes se realizan experimentos con los resultados a obtener.

# %% [markdown]
# ## Resultados del modelo

# %% [markdown]
# En la clase Beam() se definió un modelo de elementos finitos para encontrar la deformación de una viga empotrada en 2 o 3 dimensiones considerando los parámetros modificables del problema de mayor interés. Estos son:
#
# - mesh : malla del sólido con sus fronteras definidas para identificar las zonas empotradas y libres
# - order : orden de la aproximación para el modelo
# - lam ($\lambda$) : primer parámetro de Lamé, asociado con la resistencia a cargas axiales
# - mu ($\mu$) : segundo parámetro de Lamé, asociado con la resistencia a cargas cortantes
# - b : objeto CoefficientFunction que representa la carga por unidad de volumen dentro del sólido
# - T : objeto CoefficientFunction que representa la carga por unidad de superficie en la frontera del sólido
#
# Se realiza una primera demostración de como funciona la implementación computacional:

# %%
mesh = ReadGmsh('simple_brick.msh')
mesh = Mesh(mesh)
order = 2
lam = 1000
mu = 1000
b = CoefficientFunction((0,0,0))
T = CoefficientFunction((0,-0.5,0))

viga = Beam(mesh,order,lam,mu,b,T)
viga.solve(draw = True)

print(min(viga.gfu.vec))
# Out:
# WARNING: Physical groups detected - Be sure to define them for every geometrical entity.
# WebGuiWidget(value={'ngsolve_version': '6.2.2104', 'mesh_dim': 3, 'order2d': 2, 'order3d': 2, 'draw_vol': True…
# -1.477552735808667

# %% [markdown]
# Como se puede apreciar, la viga reacciona a través de deformaciones (en este caso elásticas y lineales) a las cargas aplicadas, es posible modificar el empotramiento de la viga al cambiar los atributos viga.freebnd y viga.fixedbnd para superficies libres y empotradas respectivamente. El formato de entrada de este parámetro es un string regex con los nombres de los grupos físicos separados por el carácter "|".

# %% [markdown]
# ## Análisis: parámetros de Lamé

# %% [markdown]
# Los parámetros de Lamé en la mecánica del continuo corresponden a dos magnitudes que describen las propiedades mecánicas para la deformación de un material ante la presencia de cargas. Se encuentran presentes en la ley de Hooke en tres dimensiones:
#
# $$
# \sigma = \lambda\,\hbox{tr}\,(\varepsilon) I + 2\mu\varepsilon,
# $$
#
#
# Se relacionan con el módulo elástico para esfuerzos axiales ($E$) y cortantes ($G$) de la siguiente manera:
#
# $$
# \begin{align}
# E&=\mu \frac{3\lambda + 2\mu}{\lambda + \mu},\\
# G&=\mu,
# \end{align}
# $$
#
# En el siguiente ejemplo se modeliza como una barra de acero de 15x1x1 metros se ve afectada por su peso propio:

# %%
mesh = ReadGmsh('steel_bar.msh')
mesh = Mesh(mesh)
order = 3

# parámetros de Lamé para el acero (aproximados)
lam = 76000
mu = 85000

b = CoefficientFunction((0,-7850*9.8*10**-6,0)) # peso propio
T = CoefficientFunction((0,0,0)) # carga externa

viga = Beam(mesh,order,lam,mu,b,T)
viga.freebnd = 'top'
viga.solve(draw = True)

print(f'La deflexión máxima es de: {min(viga.gfu.vec)}')
# Out:
# WARNING: Physical groups detected - Be sure to define them for every geometrical entity.
# WebGuiWidget(value={'ngsolve_version': '6.2.2104', 'mesh_dim': 3, 'order2d': 2, 'order3d': 2, 'draw_vol': True…
# La deflexión máxima es de: -0.023850413986216224

# %% [markdown]
# Los resultados de deflexión se pueden comparar con los planteados por la teoría de Euler-Bernoulli para vigas de una dimensión con el objetivo de comparar ordenes de magnitud. Según las ecuaciones de deformación en una dimensión:
#
# $$
# \varepsilon_{max} = \frac{qL^4}{8EI} = -0.0278
# $$
#
# Esta diferencia puede deberse a las diferencias en la formulación matemática del problema, pero entrega indicios de que ambos métodos entregan resultados similares.
#
# Por otro lado, esta viga se encuentra tiene una longitud (span) mayor al permitido por las normas estructurales convencionales, por lo que se pueden apreciar pequeñas deformaciones hacia el extremo final del sólido. Al variar los parámetros $\lambda$ y $\mu$ manteniendo las cargas y teniendo en cuenta que esta ecuación rige para deformaciones pequeñas, se obtienen los siguientes resultados:

# %%
import numpy as np
import pandas as pd

# %%
llam = [60000, 75000, 90000]
lmu =  [70000, 85000, 100000]

order = 2
b = CoefficientFunction((0,-3,0)) # peso propio
T = CoefficientFunction((0,0,0)) # carga externa

i_lam = 0
max_strain = np.zeros((3,3))
for lam in llam:
    i_mu = 0
    for mu in lmu:
        viga = Beam(mesh,order,lam,mu,b,T)
        viga.freebnd = 'top'
        viga.solve()
        
        max_strain[i_lam,i_mu] = min(viga.gfu.vec)
        
        i_mu += 1
    i_lam += 1

df = pd.DataFrame(max_strain,
                 index = pd.Index([f'$\lambda$ = {llam[0]}',f'$\lambda$ = {llam[1]}',f'$\lambda$ = {llam[2]}']),
                 columns = pd.Index([f'$\mu$ = {lmu[0]}',f'$\mu$ = {lmu[1]}',f'$\mu$  = {lmu[2]}']))

Draw(viga.gfu, deformation = True)

print('Valores para deformación unitaria respecto a parámetros de Lamé:')
df
# Out:
# WebGuiWidget(value={'ngsolve_version': '6.2.2104', 'mesh_dim': 3, 'order2d': 2, 'order3d': 2, 'draw_vol': True…
# Valores para deformación unitaria respecto a parámetros de Lamé:
#                    $\mu$ = 70000  $\mu$ = 85000  $\mu$  = 100000
# $\lambda$ = 60000      -1.143889      -0.994708        -0.879906
# $\lambda$ = 75000      -1.063895      -0.933776        -0.831939
# $\lambda$ = 90000      -0.994155      -0.879773        -0.788872

# %% [markdown]
# Se puede apreciar que para una distribución donde el peso propio es dominante, el módulo de elasticidad transversal $\mu$ posee una mayor importancia relativa respecto al parámetro $\lambda$, ya que el esfuerzo de la viga es mayoritariamente de momento flector.
#
# Se realiza un experimento con otra distribución de cargas para poder comparar la importancia relativa de los parámetros en cada prueba. La distribución de cargas será de tensión, aplicada en la cara del extremo final de la viga:

# %%
llam = [60000, 75000, 90000]
lmu =  [70000, 85000, 100000]

order = 2
b = CoefficientFunction((0,0,0)) # peso propio
T = CoefficientFunction((10000,0,0)) # carga externa

i_lam = 0
max_strain = np.zeros((3,3))
for lam in llam:
    i_mu = 0
    for mu in lmu:
        viga = Beam(mesh,order,lam,mu,b,T)
        viga.freebnd = 'end'
        viga.solve()
        
        max_strain[i_lam,i_mu] = max(viga.gfu.vec)
        
        i_mu += 1
    i_lam += 1

df = pd.DataFrame(max_strain,
                 index = pd.Index([f'$\lambda$ = {llam[0]}',f'$\lambda$ = {llam[1]}',f'$\lambda$ = {llam[2]}']),
                 columns = pd.Index([f'$\mu$ = {lmu[0]}',f'$\mu$ = {lmu[1]}',f'$\mu$  = {lmu[2]}']))

Draw(viga.gfu,deformation = True)

print('Valores para deformación unitaria respecto a parámetros de Lamé:')
df
# Out:
# WebGuiWidget(value={'ngsolve_version': '6.2.2104', 'mesh_dim': 3, 'order2d': 2, 'order3d': 2, 'draw_vol': True…
# Valores para deformación unitaria respecto a parámetros de Lamé:
#                    $\mu$ = 70000  $\mu$ = 85000  $\mu$  = 100000
# $\lambda$ = 60000       0.751564       0.653131         0.577552
# $\lambda$ = 75000       0.699841       0.613590         0.546349
# $\lambda$ = 90000       0.654964       0.578677         0.518419

# %% [markdown]
# Se puede ver que en el experimento de tracción pura ambos parámetros tienen efectos significativos en la deformación máxima del material, esto es porque el módulo elástico para cargas axiales ($E$) depende de ambos parámetros.
#
# También es posible generar tensiones de corte con el parámetro de esfuerzo superficial definido como condición de borde en la ecuación. Se analiza el caso en que la carga neta genera este tipo de tensiones en la barra:

# %%
llam = [60000, 75000, 90000]
lmu =  [70000, 85000, 100000]
order = 2


from math import pi

b = CoefficientFunction((0,0,0))
T = CoefficientFunction((0,5000*cos(pi*(0.5-z)),5000*cos(pi*(0.5-y))))

i_lam = 0
max_strain = np.zeros((3,3))
for lam in llam:
    i_mu = 0
    for mu in lmu:
        viga = Beam(mesh,order,lam,mu,b,T)
        viga.freebnd = 'top|bottom|left|right'
        viga.solve()
        max_strain[i_lam,i_mu] = max(viga.gfu.vec)
        
        i_mu += 1
    i_lam += 1

df = pd.DataFrame(max_strain,
                 index = pd.Index([f'$\lambda$ = {llam[0]}',f'$\lambda$ = {llam[1]}',f'$\lambda$ = {llam[2]}']),
                 columns = pd.Index([f'$\mu$ = {lmu[0]}',f'$\mu$ = {lmu[1]}',f'$\mu$  = {lmu[2]}']))

Draw(viga.gfu, deformation = True)

print('Valores para deformación unitaria respecto a parámetros de Lamé:')
df
# Out:
# WebGuiWidget(value={'ngsolve_version': '6.2.2104', 'mesh_dim': 3, 'order2d': 2, 'order3d': 2, 'draw_vol': True…
# Valores para deformación unitaria respecto a parámetros de Lamé:
#                    $\mu$ = 70000  $\mu$ = 85000  $\mu$  = 100000
# $\lambda$ = 60000       0.111201       0.082428         0.064286
# $\lambda$ = 75000       0.125782       0.093044         0.072387
# $\lambda$ = 90000       0.139248       0.102906         0.079953

# %% [markdown]
# Se puede ver que la magnitud de la deformación depende mayoritariamente del parámetro $\mu$, ya que este determina el módulo elástico para tensiones de corte, aunque el parámetro $\lambda$ también influye en la deformación del sólido en menor medida.

# %% [markdown]
# ## Shape Optimization con método del gradiente conjugado

# %% [markdown]
# Se puede definir la función objetivo del problema como la energía de deformación del sólido, esta se puede calcular de la siguiente manera:
#
# $$
# E_{def} = \frac{1}{2} \int_{\Omega} \sigma : \varepsilon
# $$
#
# Notar que esta es equivalente a la forma bilineal del problema, lo que tiene sentido ya que la formulación de la ecuación se basa en el principio de trabajos virtuales. Se puede proponer el siguiente problema de optimización en el que se minimiza la energía con la restricción de que se debe cumplir la ecuación diferencial:
#
# \begin{equation}
#             \underset{\Omega\subset \mathsf{D}}{\mbox{min}} \; J(u) := \int_\Omega \sigma : \varepsilon \; dx,
# \end{equation}
#  Sujeto a que $(\Omega,u)$ satisfacen
#  \begin{equation}
#         \int_\Omega \sigma : \varepsilon (v)  = \int_\Omega f\cdot v + \int_{\partial\Omega_T} T\cdot v,
# \end{equation}
#
# Esto se implementa computacionalmente utilizando las herramientas de shape optimization de NGSolve.

# %%
from ngsolve import *
from ngsolve.webgui import Draw
from netgen.geom2d import SplineGeometry
from ngsolve.solvers import *

# %% [markdown]
# Se genera una malla bidimensional a partir del módulo de geometría spline:

# %%
geo = SplineGeometry()

# definición de puntos
p1 = geo.AppendPoint (0,0)
p2 = geo.AppendPoint (10,0)
p3 = geo.AppendPoint (10,1)
p4 = geo.AppendPoint (0,1)

# unión de los puntos en lineas
geo.Append (["line", p1, p2], bc = 'bottom')
geo.Append (["line", p2, p3], bc = 'right')
geo.Append (["line", p3, p4], bc = 'top')
geo.Append (["line", p4, p1], bc = 'left')

# se generan los elementos y nodos
mesh = geo.GenerateMesh (maxh=0.5)

# se define el objeto de ngsolve
mesh = Mesh(mesh)

# %% [markdown]
# Se define el espacio de funciones a utilizar, en este caso vectoriales derivables. Para generar la solución de la ecuación diferencial, así como el gradiente de la forma (shape differentiation) se generan dos funciones en el espacio, <i>gfu</i> corresponde a la solución para la ecuación diferencial y <i>gfp</i> corresponde a un término de la derivada direccional, que será expresado en términos de la función de costo:

# %%
fes = VectorH1(mesh, order=2, dirichlet = 'left')
gfu = GridFunction(fes)
gfp = GridFunction(fes)

# %% [markdown]
# Se definen las funciones y operadores que se utilizan en la formulación del modelo:

# %%
lam = 1000
mu = 1000


def sigma(u):
    return lam*Id(mesh.dim) * (epsilon(u)[0]+epsilon(u)[1]+epsilon(u)[2])+ 2*mu*epsilon(u)

def epsilon(u):
    return 0.5*(grad(u) + grad(u).trans)

    
def EquationFA(u,v):
    return InnerProduct(sigma(u), epsilon(v))*dx

def CostAutoFA(u): 
    return InnerProduct(sigma(u),epsilon(u))*dx

def CostAuto2(u): 
    return CostAutoFA(u)

def SolveAdjointEquation():
    rhs = gfp.vec.CreateVector()
    rhs.data = fadjoint.vec - aAuto.mat.T * gfp.vec
    update = gfp.vec.CreateVector()
    update.data = aAuto.mat.Inverse(fes.FreeDofs()).T * rhs
    gfp.vec.data += update

def SolveDeformationEquationAuto():
    rhs = gfX.vec.CreateVector()
    rhs.data = dJOmegaAuto.vec - b.mat * gfX.vec
    update = gfX.vec.CreateVector()
    update.data = b.mat.Inverse(VEC.FreeDofs()) * rhs
    gfX.vec.data += update    

LagrangianFA = CostAutoFA(gfu) + EquationFA(gfu,gfp)

# %%
u, v = fes.TnT()

b = CoefficientFunction((0,-1))

aAuto = BilinearForm(fes)
aAuto += EquationFA(u,v) - (b*v)*dx # forma bilineal para el método de newton
aAuto.Assemble()

p, w = fes.TnT()

fadjoint = LinearForm(fes)
fadjoint += -1*(CostAutoFA(gfu)).Diff(gfu,w)

VEC = H1(mesh, order=2, dim=2)
PHI, X = VEC.TnT()

dJOmegaAuto = LinearForm(VEC)
dJOmegaAuto += LagrangianFA.DiffShape(X)

b = BilinearForm(VEC)
b += InnerProduct(grad(X),grad(PHI))*dx + InnerProduct(X,PHI)*dx

gfX = GridFunction(VEC)

Newton(aAuto, gfu, fes.FreeDofs(), printing = False)

Draw(gfu, deformation = True)

gfset = GridFunction(VEC)
gfset.Set((0,0))

gfu.Set((0,0))
scene_u = Draw (gfu, mesh, "state", deformation = True)
# Out:
# WebGuiWidget(value={'ngsolve_version': '6.2.2104', 'mesh_dim': 2, 'order2d': 2, 'order3d': 2, 'draw_vol': Fals…
# WebGuiWidget(value={'ngsolve_version': '6.2.2104', 'mesh_dim': 2, 'order2d': 2, 'order3d': 2, 'draw_vol': Fals…

# %%
#reset to and solve for initial configuration
gfset.Set((0,0))
mesh.SetDeformation(gfset)
scene_u.Redraw()
gfu.vec[:]=0
Newton(aAuto, gfu, fes.FreeDofs())

LineSearch = False


iter_max = 600
Jold = Integrate(CostAuto2(gfu), mesh)
converged = False
for k in range(iter_max):
    print('cost at iteration', k, ': ', Jold)
    mesh.SetDeformation(gfset)
    scene_u.Redraw()
    
    gfu.vec[:]=0
    Newton(aAuto, gfu, fes.FreeDofs(), printing = False)
    
    fadjoint.Assemble()
    SolveAdjointEquation()
    
    b.Assemble()
    dJOmegaAuto.Assemble()
    SolveDeformationEquationAuto()

    scale = 0.03 / Norm(gfX.vec)
    gfsetOld = gfset
    gfset.vec.data -= scale * gfX.vec
    
    Jnew = Integrate(CostAuto2(gfu), mesh)
    
    if LineSearch:
        while Jnew > Jold and scale > 1e-12:
            scale = scale / 2
            
            if scale <= 1e-12:
                converged = True
                break

            gfset.vec.data = gfsetOld.vec - scale * gfX.vec
            mesh.SetDeformation(gfset)
            
            gfu.vec[:]=0
            Newton(aAuto, gfu, fes.FreeDofs(), printing = False)
            Jnew = Integrate(CostAuto(gfu), mesh)
    
    if converged==True:
        break
    Jold = Jnew

    Redraw(blocking=True)
# Out:
# Newton iteration  0
# err =  4.503297773114681
# Newton iteration  1
# err =  6.310768728611095e-13
# cost at iteration 0 :  20.279690833340215
# cost at iteration 1 :  20.694701636194598
# cost at iteration 2 :  20.725730660356344
# cost at iteration 3 :  20.18224496448422
# cost at iteration 4 :  19.57357486254088
# cost at iteration 5 :  19.223976713294444
# cost at iteration 6 :  19.302761189234367
# cost at iteration 7 :  19.45692721456086
# cost at iteration 8 :  19.372305784000073
# cost at iteration 9 :  18.85950275684076
# cost at iteration 10 :  18.365682967940568
# cost at iteration 11 :  18.10446768860379
# cost at iteration 12 :  18.200402472010914
# cost at iteration 13 :  18.31483811817235
# cost at iteration 14 :  18.204565425124606
# cost at iteration 15 :  17.77266446310739
# cost at iteration 16 :  17.363822008143103
# cost at iteration 17 :  17.158181350534964
# cost at iteration 18 :  17.256902369977258
# cost at iteration 19 :  17.35057132232913
# cost at iteration 20 :  17.239835945366966
# cost at iteration 21 :  16.88411843309089
# cost at iteration 22 :  16.5439167959784
# cost at iteration 23 :  16.37174348598985
# cost at iteration 24 :  16.464106716681254
# cost at iteration 25 :  16.54473978179187
# cost at iteration 26 :  16.441935613830758
# cost at iteration 27 :  16.150417669120383
# cost at iteration 28 :  15.874253508086634
# cost at iteration 29 :  15.723576729480572
# cost at iteration 30 :  15.800564976434893
# cost at iteration 31 :  15.87215058096231
# cost at iteration 32 :  15.782175703863754
# cost at iteration 33 :  15.544700151775915
# cost at iteration 34 :  15.337907663718301
# cost at iteration 35 :  15.216151151601151
# cost at iteration 36 :  15.254658795464053
# cost at iteration 37 :  15.320855865874764
# cost at iteration 38 :  15.249911140280885
# cost at iteration 39 :  15.05330821705731
# cost at iteration 40 :  14.913564079739283
# cost at iteration 41 :  14.831340953687402
# cost at iteration 42 :  14.817923000850536
# cost at iteration 43 :  14.879151186098532
# cost at iteration 44 :  14.826154211519638
# cost at iteration 45 :  14.655920505391975
# cost at iteration 46 :  14.569862215646435
# cost at iteration 47 :  14.517281861946726
# cost at iteration 48 :  14.466804293816462
# cost at iteration 49 :  14.522296517252911
# cost at iteration 50 :  14.480806073667303
# cost at iteration 51 :  14.326762688919754
# cost at iteration 52 :  14.279411904863393
# cost at iteration 53 :  14.243612693562246
# cost at iteration 54 :  14.171372034045705
# cost at iteration 55 :  14.22204296855045
# cost at iteration 56 :  14.18742123914292
# cost at iteration 57 :  14.043832372602703
# cost at iteration 58 :  14.023356914964586
# cost at iteration 59 :  13.99602416058963
# cost at iteration 60 :  13.910240594271182
# cost at iteration 61 :  13.958191730253057
# cost at iteration 62 :  13.927540960703661
# cost at iteration 63 :  13.791254439542671
# cost at iteration 64 :  13.789643789841843
# cost at iteration 65 :  13.765832776222071
# cost at iteration 66 :  13.67093687880567
# cost at iteration 67 :  13.71821809770157
# cost at iteration 68 :  13.689626754390789
# cost at iteration 69 :  13.558824262174221
# cost at iteration 70 :  13.570779086440321
# cost at iteration 71 :  13.547600430478132
# cost at iteration 72 :  13.446431312493285
# cost at iteration 73 :  13.49447723468257
# cost at iteration 74 :  13.466663118770068
# cost at iteration 75 :  13.340289695699761
# cost at iteration 76 :  13.36214697109466
# cost at iteration 77 :  13.33797850253104
# cost at iteration 78 :  13.232658930405437
# cost at iteration 79 :  13.282236420575815
# cost at iteration 80 :  13.254347588363038
# cost at iteration 81 :  13.13183679021948
# cost at iteration 82 :  13.160914669486777
# cost at iteration 83 :  13.134910953097227
# cost at iteration 84 :  13.027179404595104
# cost at iteration 85 :  13.078516452974592
# cost at iteration 86 :  13.049993017011385
# cost at iteration 87 :  12.931121904319902
# cost at iteration 88 :  12.965353713330062
# cost at iteration 89 :  12.937127886443887
# cost at iteration 90 :  12.828485305542712
# cost at iteration 91 :  12.881420493941373
# cost at iteration 92 :  12.851893326373473
# cost at iteration 93 :  12.736702122643178
# cost at iteration 94 :  12.7744222149862
# cost at iteration 95 :  12.743840216108007
# cost at iteration 96 :  12.635633516751296
# cost at iteration 97 :  12.689736235523217
# cost at iteration 98 :  12.658954513014049
# cost at iteration 99 :  12.547697593319503
# cost at iteration 100 :  12.587506350819027
# cost at iteration 101 :  12.554557752465257
# cost at iteration 102 :  12.448035392540913
# cost at iteration 103 :  12.502692450954028
# cost at iteration 104 :  12.470473971075192
# cost at iteration 105 :  12.363582150293492
# cost at iteration 106 :  12.40425878878839
# cost at iteration 107 :  12.368979321760587
# cost at iteration 108 :  12.265326346728072
# cost at iteration 109 :  12.31980496142024
# cost at iteration 110 :  12.28600355246441
# cost at iteration 111 :  12.184045072631628
# cost at iteration 112 :  12.224495952900835
# cost at iteration 113 :  12.186924007893944
# cost at iteration 114 :  12.087276158027633
# cost at iteration 115 :  12.14077544982573
# cost at iteration 116 :  12.105260780847997
# cost at iteration 117 :  12.008893564935207
# cost at iteration 118 :  12.048130526443195
# cost at iteration 119 :  12.008285558448371
# cost at iteration 120 :  11.913721356837407
# cost at iteration 121 :  11.965421864173639
# cost at iteration 122 :  11.928068293635475
# cost at iteration 123 :  11.83798097165056
# cost at iteration 124 :  11.875124770149352
# cost at iteration 125 :  11.832999820800126
# cost at iteration 126 :  11.744512277169285
# cost at iteration 127 :  11.793628070571787
# cost at iteration 128 :  11.754310354793086
# cost at iteration 129 :  11.671155184925928
# cost at iteration 130 :  11.70545647878933
# cost at iteration 131 :  11.661019968522316
# cost at iteration 132 :  11.579474162691065
# cost at iteration 133 :  11.625306161152928
# cost at iteration 134 :  11.583900581428187
# cost at iteration 135 :  11.508226898516606
# cost at iteration 136 :  11.539093844000027
# cost at iteration 137 :  11.492297487924986
# cost at iteration 138 :  11.418384899122348
# cost at iteration 139 :  11.460368706460441
# cost at iteration 140 :  11.416758385049913
# cost at iteration 141 :  11.348958332959079
# cost at iteration 142 :  11.375978404058532
# cost at iteration 143 :  11.326768836089647
# cost at iteration 144 :  11.260971231918434
# cost at iteration 145 :  11.298710526687751
# cost at iteration 146 :  11.252793501677838
# cost at iteration 147 :  11.19307038179169
# cost at iteration 148 :  11.216016507081102
# cost at iteration 149 :  11.164348353399939
# cost at iteration 150 :  11.10692151898007
# cost at iteration 151 :  11.14020015926618
# cost at iteration 152 :  11.09189845779645
# cost at iteration 153 :  11.040262131425767
# cost at iteration 154 :  11.059079328528494
# cost at iteration 155 :  11.00492751654283
# cost at iteration 156 :  10.955908744443821
# cost at iteration 157 :  10.98468035298699
# cost at iteration 158 :  10.933948179925418
# cost at iteration 159 :  10.890234464525914
# cost at iteration 160 :  10.905010080098865
# cost at iteration 161 :  10.848379474055866
# cost at iteration 162 :  10.807615571409503
# cost at iteration 163 :  10.831975434578114
# cost at iteration 164 :  10.77880489416402
# cost at iteration 165 :  10.742710495997112
# cost at iteration 166 :  10.753635659529523
# cost at iteration 167 :  10.694566799382098
# cost at iteration 168 :  10.661754648997299
# cost at iteration 169 :  10.681902309111742
# cost at iteration 170 :  10.626325766516018
# cost at iteration 171 :  10.597448917558937
# cost at iteration 172 :  10.604779465106922
# cost at iteration 173 :  10.543350096380442
# cost at iteration 174 :  10.518080862000643
# cost at iteration 175 :  10.534281792132631
# cost at iteration 176 :  10.47637081756887
# cost at iteration 177 :  10.454249768459237
# cost at iteration 178 :  10.458272618408847
# cost at iteration 179 :  10.39459554817381
# cost at iteration 180 :  10.376395561030806
# cost at iteration 181 :  10.388947842559762
# cost at iteration 182 :  10.328809378017052
# cost at iteration 183 :  10.312954246926926
# cost at iteration 184 :  10.31396199142938
# cost at iteration 185 :  10.24818035448824
# cost at iteration 186 :  10.236544749026507
# cost at iteration 187 :  10.245753529686905
# cost at iteration 188 :  10.183524305129085
# cost at iteration 189 :  10.173440787661013
# cost at iteration 190 :  10.171714636337335
# cost at iteration 191 :  10.103995831934576
# cost at iteration 192 :  10.098413681305324
# cost at iteration 193 :  10.104573682242878
# cost at iteration 194 :  10.040413969771091
# cost at iteration 195 :  10.03561934325979
# cost at iteration 196 :  10.031419075456443
# cost at iteration 197 :  9.96194850901334
# cost at iteration 198 :  9.961919952027026
# cost at iteration 199 :  9.965304856772834
# cost at iteration 200 :  9.899392482208137
# cost at iteration 201 :  9.899425225942391
# cost at iteration 202 :  9.892984320918455
# cost at iteration 203 :  9.821959794665418
# cost at iteration 204 :  9.827006477207025
# cost at iteration 205 :  9.827863519251226
# cost at iteration 206 :  9.760388776627275
# cost at iteration 207 :  9.764813323746901
# cost at iteration 208 :  9.75633754738182
# cost at iteration 209 :  9.683964817417317
# cost at iteration 210 :  9.693635176391764
# cost at iteration 211 :  9.692183290659964
# cost at iteration 212 :  9.623345128312728
# cost at iteration 213 :  9.631753106992969
# cost at iteration 214 :  9.621421190099355
# cost at iteration 215 :  9.547910928968767
# cost at iteration 216 :  9.561781713811586
# cost at iteration 217 :  9.55821191761971
# cost at iteration 218 :  9.488215543080267
# cost at iteration 219 :  9.500224581413068
# cost at iteration 220 :  9.488190016509737
# cost at iteration 221 :  9.413756224658135
# cost at iteration 222 :  9.431431382700888
# cost at iteration 223 :  9.42590840657433
# cost at iteration 224 :  9.35496431001755
# cost at iteration 225 :  9.370215189629771
# cost at iteration 226 :  9.356608504940946
# cost at iteration 227 :  9.281468301060166
# cost at iteration 228 :  9.302576063715819
# cost at iteration 229 :  9.29524056673723
# cost at iteration 230 :  9.223564882316499
# cost at iteration 231 :  9.24171757973789
# cost at iteration 232 :  9.226648696169606
# cost at iteration 233 :  9.151023367027653
# cost at iteration 234 :  9.175212118416614
# cost at iteration 235 :  9.166183065661619
# cost at iteration 236 :  9.09399915726787
# cost at iteration 237 :  9.114728123689446
# cost at iteration 238 :  9.098288569945407
# cost at iteration 239 :  9.022405750140258
# cost at iteration 240 :  9.049339058994923
# cost at iteration 241 :  9.038716011241517
# cost at iteration 242 :  8.966257160876719
# cost at iteration 243 :  8.989246060727462
# cost at iteration 244 :  8.971510931293832
# cost at iteration 245 :  8.895607788232958
# cost at iteration 246 :  8.924958842661665
# cost at iteration 247 :  8.912824024208533
# cost at iteration 248 :  8.840337094065497
# cost at iteration 249 :  8.865273148754039
# cost at iteration 250 :  8.84630275724125
# cost at iteration 251 :  8.770630054176838
# cost at iteration 252 :  8.802075657602302
# cost at iteration 253 :  8.788495742195753
# cost at iteration 254 :  8.716245653001634
# cost at iteration 255 :  8.742813718951414
# cost at iteration 256 :  8.722654940147217
# cost at iteration 257 :  8.647481819094569
# cost at iteration 258 :  8.680696086424788
# cost at iteration 259 :  8.665723687642789
# cost at iteration 260 :  8.593998482839611
# cost at iteration 261 :  8.62187503820826
# cost at iteration 262 :  8.600562357501298
# cost at iteration 263 :  8.52618160284974
# cost at iteration 264 :  8.56082954491622
# cost at iteration 265 :  8.544504426886485
# cost at iteration 266 :  8.473620551516184
# cost at iteration 267 :  8.502467883284659
# cost at iteration 268 :  8.48002419048903
# cost at iteration 269 :  8.406757581752522
# cost at iteration 270 :  8.442488892890484
# cost at iteration 271 :  8.424838938516206
# cost at iteration 272 :  8.355146133630607
# cost at iteration 273 :  8.38460721481439
# cost at iteration 274 :  8.361044397653059
# cost at iteration 275 :  8.289247519761187
# cost at iteration 276 :  8.325691095719927
# cost at iteration 277 :  8.306733089512345
# cost at iteration 278 :  8.238617982850203
# cost at iteration 279 :  8.268312804962394
# cost at iteration 280 :  8.243632221103733
# cost at iteration 281 :  8.173697774436313
# cost at iteration 282 :  8.210457778297918
# cost at iteration 283 :  8.19019808506486
# cost at iteration 284 :  8.124085179199223
# cost at iteration 285 :  8.15360962164482
# cost at iteration 286 :  8.12780256144938
# cost at iteration 287 :  8.060160844349875
# cost at iteration 288 :  8.096815462693558
# cost at iteration 289 :  8.075250715715871
# cost at iteration 290 :  8.011599137702728
# cost at iteration 291 :  8.040527717201359
# cost at iteration 292 :  8.01357601374636
# cost at iteration 293 :  7.948690952700599
# cost at iteration 294 :  7.984795234223831
# cost at iteration 295 :  7.96191318814352
# cost at iteration 296 :  7.901207468985076
# cost at iteration 297 :  7.929101340952718
# cost at iteration 298 :  7.9009783354680225
# cost at iteration 299 :  7.83933742068288
# cost at iteration 300 :  7.874431575641423
# cost at iteration 301 :  7.850212325177854
# cost at iteration 302 :  7.792945905711941
# cost at iteration 303 :  7.819367046729449
# cost at iteration 304 :  7.790039163110773
# cost at iteration 305 :  7.73213618230093
# cost at iteration 306 :  7.765760205470612
# cost at iteration 307 :  7.740178007036037
# cost at iteration 308 :  7.686829376042041
# cost at iteration 309 :  7.711360767585532
# cost at iteration 310 :  7.680789964789465
# cost at iteration 311 :  7.627100726155381
# cost at iteration 312 :  7.65881502376764
# cost at iteration 313 :  7.631840959001105
# cost at iteration 314 :  7.582844323100796
# cost at iteration 315 :  7.6051142368797455
# cost at iteration 316 :  7.573261562697574
# cost at iteration 317 :  7.524214784560488
# cost at iteration 318 :  7.553624752455796
# cost at iteration 319 :  7.525230415015085
# cost at iteration 320 :  7.4809450851589325
# cost at iteration 321 :  7.500651748638173
# cost at iteration 322 :  7.467482096261022
# cost at iteration 323 :  7.42342976280826
# cost at iteration 324 :  7.4502105438494
# cost at iteration 325 :  7.420372809674073
# cost at iteration 326 :  7.381057078170612
# cost at iteration 327 :  7.397989007713576
# cost at iteration 328 :  7.363477010276523
# cost at iteration 329 :  7.32466980926605
# cost at iteration 330 :  7.348586675313242
# cost at iteration 331 :  7.317293488896134
# cost at iteration 332 :  7.283088667036372
# cost at iteration 333 :  7.297136717009836
# cost at iteration 334 :  7.261273632890813
# cost at iteration 335 :  7.227846800508504
# cost at iteration 336 :  7.248767588230106
# cost at iteration 337 :  7.216024734937211
# cost at iteration 338 :  7.186953025629902
# cost at iteration 339 :  7.198113025703206
# cost at iteration 340 :  7.160914763710343
# cost at iteration 341 :  7.132887839934025
# cost at iteration 342 :  7.15078688797419
# cost at iteration 343 :  7.1166263303352215
# cost at iteration 344 :  7.092603459277029
# cost at iteration 345 :  7.100972883489914
# cost at iteration 346 :  7.0624907007233135
# cost at iteration 347 :  7.03978278710783
# cost at iteration 348 :  7.05474089827074
# cost at iteration 349 :  7.019233570863692
# cost at iteration 350 :  7.000096100761878
# cost at iteration 351 :  7.005875160525171
# cost at iteration 352 :  6.966215372010376
# cost at iteration 353 :  6.948678890602625
# cost at iteration 354 :  6.960893292517756
# cost at iteration 355 :  6.924177765733856
# cost at iteration 356 :  6.909731089250918
# cost at iteration 357 :  6.913255402374479
# cost at iteration 358 :  6.872633505896939
# cost at iteration 359 :  6.8601248970470055
# cost at iteration 360 :  6.869972909385764
# cost at iteration 361 :  6.832350825948024
# cost at iteration 362 :  6.822480543394504
# cost at iteration 363 :  6.824383775472876
# cost at iteration 364 :  6.783343346760659
# cost at iteration 365 :  6.77594563726521
# cost at iteration 366 :  6.784303466289539
# cost at iteration 367 :  6.746734373214176
# cost at iteration 368 :  6.74190689709931
# cost at iteration 369 :  6.744002899992859
# cost at iteration 370 :  6.704958146585262
# cost at iteration 371 :  6.704572329256299
# cost at iteration 372 :  6.715224490908556
# cost at iteration 373 :  6.685247148246197
# cost at iteration 374 :  6.694232454313583
# cost at iteration 375 :  6.71290298420372
# cost at iteration 376 :  6.722919782256796
# cost at iteration 377 :  6.823692314002213
# cost at iteration 378 :  7.180707975775257
# cost at iteration 379 :  11.432635690734568
# cost at iteration 380 :  6.961508372876007
# cost at iteration 381 :  6.696008701328228
# cost at iteration 382 :  6.600070184172163
# cost at iteration 383 :  6.551006589982832
# cost at iteration 384 :  6.577806797458602
# cost at iteration 385 :  6.550410341165039
# cost at iteration 386 :  6.577065527486354
# cost at iteration 387 :  6.549799365753296
# cost at iteration 388 :  6.576315412379108
# cost at iteration 389 :  6.549193021992286
# cost at iteration 390 :  6.575572302493685
# cost at iteration 391 :  6.548586895700487
# cost at iteration 392 :  6.574824569968218
# cost at iteration 393 :  6.547976071613149
# cost at iteration 394 :  6.574073409208562
# cost at iteration 395 :  6.547367177958558
# cost at iteration 396 :  6.573323900182788
# cost at iteration 397 :  6.546756362583463
# cost at iteration 398 :  6.572570442301903
# cost at iteration 399 :  6.5461433399137245
# cost at iteration 400 :  6.571814747194154
# cost at iteration 401 :  6.545530479643222
# cost at iteration 402 :  6.571058346901616
# cost at iteration 403 :  6.544915428624353
# cost at iteration 404 :  6.570298347630639
# cost at iteration 405 :  6.544298751631445
# cost at iteration 406 :  6.56953603102923
# cost at iteration 407 :  6.543681154661159
# cost at iteration 408 :  6.568771661906276
# cost at iteration 409 :  6.543061307398206
# cost at iteration 410 :  6.568003639627904
# cost at iteration 411 :  6.54243975400601
# cost at iteration 412 :  6.5672327844349665
# cost at iteration 413 :  6.541816536506478
# cost at iteration 414 :  6.56645884100548
# cost at iteration 415 :  6.541190907041514
# cost at iteration 416 :  6.565680867171453
# cost at iteration 417 :  6.54056320481465
# cost at iteration 418 :  6.564899276656237
# cost at iteration 419 :  6.53993320917194
# cost at iteration 420 :  6.564113589373552
# cost at iteration 421 :  6.5393004683891185
# cost at iteration 422 :  6.563323169532011
# cost at iteration 423 :  6.538665103770353
# cost at iteration 424 :  6.562528081324056
# cost at iteration 425 :  6.538026786100339
# cost at iteration 426 :  6.561727720823043
# cost at iteration 427 :  6.537385177174636
# cost at iteration 428 :  6.560921530080301
# cost at iteration 429 :  6.536740199542308
# cost at iteration 430 :  6.560109250871782
# cost at iteration 431 :  6.536091451647845
# cost at iteration 432 :  6.55929014391049
# cost at iteration 433 :  6.535438581753588
# cost at iteration 434 :  6.558463545201751
# cost at iteration 435 :  6.5347813142037
# cost at iteration 436 :  6.557628839189194
# cost at iteration 437 :  6.5341191398959335
# cost at iteration 438 :  6.556785040283076
# cost at iteration 439 :  6.533451576903939
# cost at iteration 440 :  6.5559311633878
# cost at iteration 441 :  6.5327780988936714
# cost at iteration 442 :  6.555066077626574
# cost at iteration 443 :  6.532097978086653
# cost at iteration 444 :  6.554188279044559
# cost at iteration 445 :  6.531410432996826
# cost at iteration 446 :  6.553296074765653
# cost at iteration 447 :  6.530714516344614
# cost at iteration 448 :  6.5523873627247
# cost at iteration 449 :  6.5300090143206715
# cost at iteration 450 :  6.551459433257227
# cost at iteration 451 :  6.52929247455103
# cost at iteration 452 :  6.5505089066448035
# cost at iteration 453 :  6.528563033416015
# cost at iteration 454 :  6.5495313125572485
# cost at iteration 455 :  6.527818246656505
# cost at iteration 456 :  6.54852058300801
# cost at iteration 457 :  6.52705489158521
# cost at iteration 458 :  6.547468299175126
# cost at iteration 459 :  6.526268530971051
# cost at iteration 460 :  6.546362255096322
# cost at iteration 461 :  6.525452936062556
# cost at iteration 462 :  6.545184414687705
# cost at iteration 463 :  6.524599470652834
# cost at iteration 464 :  6.543910182703255
# cost at iteration 465 :  6.523698510839649
# cost at iteration 466 :  6.542538018120354
# cost at iteration 467 :  6.6087644461750585
# cost at iteration 468 :  6.559031307675753
# cost at iteration 469 :  6.601525475412818
# cost at iteration 470 :  6.557259129125975
# cost at iteration 471 :  6.6003732276384195
# cost at iteration 472 :  6.556639503318283
# cost at iteration 473 :  6.599327578059971
# cost at iteration 474 :  6.555648756198049
# cost at iteration 475 :  6.597431635563645
# cost at iteration 476 :  6.554598986553724
# cost at iteration 477 :  6.596368417691541
# cost at iteration 478 :  6.553897399514345
# cost at iteration 479 :  6.595197405393987
# cost at iteration 480 :  6.553028090555386
# cost at iteration 481 :  6.593922185356697
# cost at iteration 482 :  6.552196733278625
# cost at iteration 483 :  6.59287984317277
# cost at iteration 484 :  6.551472232664958
# cost at iteration 485 :  6.591765002099625
# cost at iteration 486 :  6.5506679860765065
# cost at iteration 487 :  6.590670027726388
# cost at iteration 488 :  6.54990863104466
# cost at iteration 489 :  6.589656444731387
# cost at iteration 490 :  6.549186378317225
# cost at iteration 491 :  6.588614684161443
# cost at iteration 492 :  6.548430054114732
# cost at iteration 493 :  6.587604285367081
# cost at iteration 494 :  6.5477071044758
# cost at iteration 495 :  6.5866266936254085
# cost at iteration 496 :  6.5469970297761915
# cost at iteration 497 :  6.585643847498241
# cost at iteration 498 :  6.546275279436259
# cost at iteration 499 :  6.584685688902909
# cost at iteration 500 :  6.5455755924117
# cost at iteration 501 :  6.583743773591185
# cost at iteration 502 :  6.544880680872864
# cost at iteration 503 :  6.5828060327846485
# cost at iteration 504 :  6.544184226784589
# cost at iteration 505 :  6.58188587378431
# cost at iteration 506 :  6.5435018445810655
# cost at iteration 507 :  6.580976080873928
# cost at iteration 508 :  6.542822000783547
# cost at iteration 509 :  6.580073488698921
# cost at iteration 510 :  6.5421446716803615
# cost at iteration 511 :  6.57918351923611
# cost at iteration 512 :  6.541476389873557
# cost at iteration 513 :  6.57830158724952
# cost at iteration 514 :  6.540810319019339
# cost at iteration 515 :  6.577427228863425
# cost at iteration 516 :  6.540148012663169
# cost at iteration 517 :  6.576562341103417
# cost at iteration 518 :  6.539491770024152
# cost at iteration 519 :  6.575704300925292
# cost at iteration 520 :  6.538837860349541
# cost at iteration 521 :  6.5748532662675405
# cost at iteration 522 :  6.538187782527593
# cost at iteration 523 :  6.5740097007846465
# cost at iteration 524 :  6.53754203971278
# cost at iteration 525 :  6.573172158683938
# cost at iteration 526 :  6.536898733232724
# cost at iteration 527 :  6.572340817451072
# cost at iteration 528 :  6.536258903145276
# cost at iteration 529 :  6.571515616554575
# cost at iteration 530 :  6.535622400561822
# cost at iteration 531 :  6.570695754541309
# cost at iteration 532 :  6.534988319847172
# cost at iteration 533 :  6.569881308152419
# cost at iteration 534 :  6.534357265291078
# cost at iteration 535 :  6.569072061045755
# cost at iteration 536 :  6.533728926268486
# cost at iteration 537 :  6.568267549540039
# cost at iteration 538 :  6.533102895031304
# cost at iteration 539 :  6.567467761825473
# cost at iteration 540 :  6.532479468966614
# cost at iteration 541 :  6.566672462420348
# cost at iteration 542 :  6.531858356728117
# cost at iteration 543 :  6.565881362066661
# cost at iteration 544 :  6.531239379968603
# cost at iteration 545 :  6.565094394635694
# cost at iteration 546 :  6.530622650829007
# cost at iteration 547 :  6.5643113487375695
# cost at iteration 548 :  6.530007944407736
# cost at iteration 549 :  6.563532025884482
# cost at iteration 550 :  6.529395177426614
# cost at iteration 551 :  6.5627563332581085
# cost at iteration 552 :  6.528784362950814
# cost at iteration 553 :  6.561984091832731
# cost at iteration 554 :  6.52817533959222
# cost at iteration 555 :  6.561215151877647
# cost at iteration 556 :  6.527568057754777
# cost at iteration 557 :  6.560449411247325
# cost at iteration 558 :  6.526962484053633
# cost at iteration 559 :  6.559686720081798
# cost at iteration 560 :  6.526358504178874
# cost at iteration 561 :  6.558926956405216
# cost at iteration 562 :  6.525756077368627
# cost at iteration 563 :  6.558170018240981
# cost at iteration 564 :  6.525155152512363
# cost at iteration 565 :  6.557415779066607
# cost at iteration 566 :  6.524555646300407
# cost at iteration 567 :  6.55666413403855
# cost at iteration 568 :  6.5239575186129635
# cost at iteration 569 :  6.555914985873716
# cost at iteration 570 :  6.5233607146148875
# cost at iteration 571 :  6.555168225897435
# cost at iteration 572 :  6.522765170109059
# cost at iteration 573 :  6.5544237608345846
# cost at iteration 574 :  6.522170844088557
# cost at iteration 575 :  6.553681499780042
# cost at iteration 576 :  6.521577683850196
# cost at iteration 577 :  6.552941347499348
# cost at iteration 578 :  6.520985636603648
# cost at iteration 579 :  6.552203219168495
# cost at iteration 580 :  6.520394661023878
# cost at iteration 581 :  6.5514670304436216
# cost at iteration 582 :  6.5198047083297785
# cost at iteration 583 :  6.550732696186475
# cost at iteration 584 :  6.5192157325172655
# cost at iteration 585 :  6.55000013808929
# cost at iteration 586 :  6.518627692786059
# cost at iteration 587 :  6.549269277824048
# cost at iteration 588 :  6.51804054427177
# cost at iteration 589 :  6.548540037845325
# cost at iteration 590 :  6.51745424510407
# cost at iteration 591 :  6.547812345003635
# cost at iteration 592 :  6.516868755554024
# cost at iteration 593 :  6.547086126130219
# cost at iteration 594 :  6.516284034017906
# cost at iteration 595 :  6.546361309376768
# cost at iteration 596 :  6.515700041244409
# cost at iteration 597 :  6.545637825681349
# cost at iteration 598 :  6.515116738758151
# cost at iteration 599 :  6.544915606077635
